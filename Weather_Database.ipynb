# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import gmaps
import requests

import time
from datetime import datetime

# Import the API/gkey key.
from config import g_key
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=55d4171df77f4f72e17f82fa2d37fc21

# %%
city_weather = requests.get(url)
city_weather
# Out:
# <Response [400]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_descr,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint pete beach
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | honningsvag
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 1 | osoyoos
# Processing Record 9 of Set 1 | bairiki
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | kambove
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | nador
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | kavieng
# Processing Record 20 of Set 1 | karratha
# Processing Record 21 of Set 1 | quatre cocos
# Processing Record 22 of Set 1 | olafsvik
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | havre-saint-pierre
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | tabuk
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | muromtsevo
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | newnan
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | coquimbo
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | makakilo city
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | pauini
# Processing Record 44 of Set 1 | saint-louis
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | sao joao da barra
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | zlitan
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | victoria
# Processing Record 4 of Set 2 | kuytun
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | denzlingen
# Processing Record 7 of Set 2 | huilong
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | gilbues
# Processing Record 12 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 2 | zhigansk
# Processing Record 14 of Set 2 | sohag
# Processing Record 15 of Set 2 | gushikawa
# Processing Record 16 of Set 2 | santa luzia
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | fallon
# Processing Record 19 of Set 2 | ahipara
# Processing Record 20 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 2 | port lincoln
# Processing Record 22 of Set 2 | bubaque
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | kharp
# Processing Record 28 of Set 2 | vila franca do campo
# Processing Record 29 of Set 2 | mount gambier
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | ndungu
# Processing Record 33 of Set 2 | ahar
# Processing Record 34 of Set 2 | assomada
# Processing Record 35 of Set 2 | gravatai
# Processing Record 36 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 2 | marquette
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | tessalit
# Processing Record 44 of Set 2 | kloulklubed
# Processing Record 45 of Set 2 | calabozo
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | george
# Processing Record 49 of Set 2 | halifax
# Processing Record 50 of Set 2 | mwense
# Processing Record 1 of Set 3 | boda
# Processing Record 2 of Set 3 | kargil
# Processing Record 3 of Set 3 | saint-joseph
# Processing Record 4 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 3 | bud
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | alamor
# Processing Record 8 of Set 3 | shalinskoye
# Processing Record 9 of Set 3 | morondava
# Processing Record 10 of Set 3 | nara
# Processing Record 11 of Set 3 | baykit
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | yar-sale
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | cabra
# Processing Record 16 of Set 3 | mahajanga
# Processing Record 17 of Set 3 | calama
# Processing Record 18 of Set 3 | aykhal
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | wagar
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | san borja
# Processing Record 23 of Set 3 | flinders
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | geraldton
# Processing Record 30 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | waddan
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | stornoway
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | zhezkazgan
# Processing Record 39 of Set 3 | alofi
# Processing Record 40 of Set 3 | mapiripan
# Processing Record 41 of Set 3 | isabela
# Processing Record 42 of Set 3 | caravelas
# Processing Record 43 of Set 3 | margate
# Processing Record 44 of Set 3 | sibolga
# Processing Record 45 of Set 3 | kushima
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | dikson
# Processing Record 48 of Set 3 | villa union
# Processing Record 49 of Set 3 | hasaki
# Processing Record 50 of Set 3 | port alfred
# Processing Record 1 of Set 4 | iskilip
# Processing Record 2 of Set 4 | ewo
# Processing Record 3 of Set 4 | punta alta
# Processing Record 4 of Set 4 | bonavista
# Processing Record 5 of Set 4 | cap-aux-meules
# Processing Record 6 of Set 4 | sarankhola
# Processing Record 7 of Set 4 | henties bay
# Processing Record 8 of Set 4 | bima
# Processing Record 9 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | axim
# Processing Record 13 of Set 4 | penzance
# Processing Record 14 of Set 4 | kamaishi
# Processing Record 15 of Set 4 | ribeira grande
# Processing Record 16 of Set 4 | vao
# Processing Record 17 of Set 4 | buala
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | mahaicony
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint-denis
# Processing Record 21 of Set 4 | millinocket
# Processing Record 22 of Set 4 | ulladulla
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | marapanim
# Processing Record 25 of Set 4 | moerai
# Processing Record 26 of Set 4 | tura
# Processing Record 27 of Set 4 | dongsheng
# Processing Record 28 of Set 4 | la ronge
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | coihaique
# Processing Record 32 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | dover
# Processing Record 35 of Set 4 | hamilton
# Processing Record 36 of Set 4 | centralia
# Processing Record 37 of Set 4 | argelia
# Processing Record 38 of Set 4 | moba
# Processing Record 39 of Set 4 | la asuncion
# Processing Record 40 of Set 4 | marystown
# Processing Record 41 of Set 4 | acarau
# Processing Record 42 of Set 4 | nelson bay
# Processing Record 43 of Set 4 | itaituba
# Processing Record 44 of Set 4 | doha
# Processing Record 45 of Set 4 | tsimlyansk
# Processing Record 46 of Set 4 | esperance
# Processing Record 47 of Set 4 | gudivada
# Processing Record 48 of Set 4 | sioux lookout
# Processing Record 49 of Set 4 | kouroussa
# Processing Record 50 of Set 4 | dzhida
# Processing Record 1 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 5 | kieta
# Processing Record 3 of Set 5 | pareora
# Processing Record 4 of Set 5 | manono
# Processing Record 5 of Set 5 | khash
# Processing Record 6 of Set 5 | lata
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | jhol
# Processing Record 9 of Set 5 | bhadrak
# Processing Record 10 of Set 5 | plettenberg bay
# Processing Record 11 of Set 5 | virginia beach
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | ukiah
# Processing Record 14 of Set 5 | guarapari
# Processing Record 15 of Set 5 | kigoma
# Processing Record 16 of Set 5 | nadym
# Processing Record 17 of Set 5 | yellowknife
# Processing Record 18 of Set 5 | altea
# Processing Record 19 of Set 5 | laguna
# Processing Record 20 of Set 5 | bila krynytsya
# Processing Record 21 of Set 5 | codrington
# Processing Record 22 of Set 5 | poum
# Processing Record 23 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 5 | novaya zaimka
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | campagna
# Processing Record 27 of Set 5 | yumen
# Processing Record 28 of Set 5 | port augusta
# Processing Record 29 of Set 5 | lahaina
# Processing Record 30 of Set 5 | urozhaynoye
# Processing Record 31 of Set 5 | northam
# Processing Record 32 of Set 5 | comodoro rivadavia
# Processing Record 33 of Set 5 | pathein
# Processing Record 34 of Set 5 | severnoye
# Processing Record 35 of Set 5 | chuy
# Processing Record 36 of Set 5 | nantucket
# Processing Record 37 of Set 5 | sobolevo
# Processing Record 38 of Set 5 | dzaoudzi
# Processing Record 39 of Set 5 | jalingo
# Processing Record 40 of Set 5 | sorland
# Processing Record 41 of Set 5 | srandakan
# Processing Record 42 of Set 5 | mulchen
# Processing Record 43 of Set 5 | montbrison
# Processing Record 44 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 5 | tilichiki
# Processing Record 46 of Set 5 | hami
# Processing Record 47 of Set 5 | sinnamary
# Processing Record 48 of Set 5 | vila do maio
# Processing Record 49 of Set 5 | domanivka
# Processing Record 50 of Set 5 | broken hill
# Processing Record 1 of Set 6 | ndele
# Processing Record 2 of Set 6 | fairbanks
# Processing Record 3 of Set 6 | mweka
# Processing Record 4 of Set 6 | kasungu
# Processing Record 5 of Set 6 | ibra
# Processing Record 6 of Set 6 | terrace
# Processing Record 7 of Set 6 | rocha
# Processing Record 8 of Set 6 | lipari
# Processing Record 9 of Set 6 | lardos
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | kargapolye
# City not found. Skipping...
# Processing Record 12 of Set 6 | okmulgee
# Processing Record 13 of Set 6 | roald
# Processing Record 14 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 6 | shenjiamen
# Processing Record 16 of Set 6 | vardo
# Processing Record 17 of Set 6 | luga
# Processing Record 18 of Set 6 | paamiut
# Processing Record 19 of Set 6 | pemangkat
# Processing Record 20 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 21 of Set 6 | opuwo
# Processing Record 22 of Set 6 | nishihara
# Processing Record 23 of Set 6 | najran
# Processing Record 24 of Set 6 | camopi
# Processing Record 25 of Set 6 | camacha
# Processing Record 26 of Set 6 | vostok
# Processing Record 27 of Set 6 | chapais
# Processing Record 28 of Set 6 | xinye
# Processing Record 29 of Set 6 | nouadhibou
# Processing Record 30 of Set 6 | pangody
# Processing Record 31 of Set 6 | natal
# Processing Record 32 of Set 6 | port blair
# Processing Record 33 of Set 6 | achacachi
# Processing Record 34 of Set 6 | fort nelson
# Processing Record 35 of Set 6 | port-gentil
# Processing Record 36 of Set 6 | aitape
# Processing Record 37 of Set 6 | kuldiga
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | nacogdoches
# Processing Record 40 of Set 6 | javanrud
# Processing Record 41 of Set 6 | kununurra
# Processing Record 42 of Set 6 | porto murtinho
# Processing Record 43 of Set 6 | trelew
# Processing Record 44 of Set 6 | gladstone
# Processing Record 45 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 6 | maniitsoq
# Processing Record 47 of Set 6 | rosetta
# Processing Record 48 of Set 6 | pochutla
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | vuktyl
# Processing Record 1 of Set 7 | necochea
# Processing Record 2 of Set 7 | winsum
# Processing Record 3 of Set 7 | poso
# Processing Record 4 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | viru
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 7 | kaeo
# Processing Record 10 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 11 of Set 7 | jacqueville
# Processing Record 12 of Set 7 | lieksa
# Processing Record 13 of Set 7 | cabo san lucas
# Processing Record 14 of Set 7 | cidreira
# Processing Record 15 of Set 7 | hof
# Processing Record 16 of Set 7 | sao miguel do araguaia
# Processing Record 17 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 7 | saskylakh
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | grand baie
# Processing Record 21 of Set 7 | khora
# Processing Record 22 of Set 7 | dire
# Processing Record 23 of Set 7 | kang
# Processing Record 24 of Set 7 | portland
# Processing Record 25 of Set 7 | ahuimanu
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | luena
# Processing Record 28 of Set 7 | olpad
# Processing Record 29 of Set 7 | huarmey
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | pitkyaranta
# Processing Record 32 of Set 7 | almaznyy
# Processing Record 33 of Set 7 | half moon bay
# Processing Record 34 of Set 7 | zhangye
# Processing Record 35 of Set 7 | mulege
# Processing Record 36 of Set 7 | qaqortoq
# Processing Record 37 of Set 7 | springdale
# Processing Record 38 of Set 7 | moranbah
# Processing Record 39 of Set 7 | zonguldak
# Processing Record 40 of Set 7 | lavrentiya
# Processing Record 41 of Set 7 | rutland
# Processing Record 42 of Set 7 | ozernovskiy
# Processing Record 43 of Set 7 | dicabisagan
# Processing Record 44 of Set 7 | puerto escondido
# Processing Record 45 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 7 | nacala
# Processing Record 47 of Set 7 | chokurdakh
# Processing Record 48 of Set 7 | kathmandu
# Processing Record 49 of Set 7 | mchinji
# Processing Record 50 of Set 7 | lyuban
# Processing Record 1 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 8 | burgersdorp
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | ryotsu
# Processing Record 5 of Set 8 | sakakah
# Processing Record 6 of Set 8 | asosa
# Processing Record 7 of Set 8 | saint-augustin
# Processing Record 8 of Set 8 | contamana
# Processing Record 9 of Set 8 | bentiu
# Processing Record 10 of Set 8 | blois
# Processing Record 11 of Set 8 | bela
# Processing Record 12 of Set 8 | prestea
# Processing Record 13 of Set 8 | avera
# Processing Record 14 of Set 8 | kiruna
# Processing Record 15 of Set 8 | saryozek
# Processing Record 16 of Set 8 | christchurch
# Processing Record 17 of Set 8 | bhadrachalam
# Processing Record 18 of Set 8 | savannah bight
# Processing Record 19 of Set 8 | hegang
# Processing Record 20 of Set 8 | ballina
# Processing Record 21 of Set 8 | dargaville
# Processing Record 22 of Set 8 | suruc
# Processing Record 23 of Set 8 | kavaratti
# Processing Record 24 of Set 8 | cururupu
# Processing Record 25 of Set 8 | fatikchhari
# City not found. Skipping...
# Processing Record 26 of Set 8 | samarai
# Processing Record 27 of Set 8 | diego de almagro
# Processing Record 28 of Set 8 | seraing
# Processing Record 29 of Set 8 | los llanos de aridane
# Processing Record 30 of Set 8 | adre
# Processing Record 31 of Set 8 | balsa
# Processing Record 32 of Set 8 | chilliwack
# Processing Record 33 of Set 8 | ramsgate
# Processing Record 34 of Set 8 | tromso
# Processing Record 35 of Set 8 | tommot
# Processing Record 36 of Set 8 | podyuga
# Processing Record 37 of Set 8 | nevyansk
# Processing Record 38 of Set 8 | rogun
# City not found. Skipping...
# Processing Record 39 of Set 8 | eureka
# Processing Record 40 of Set 8 | gunjur
# Processing Record 41 of Set 8 | hervey bay
# Processing Record 42 of Set 8 | yagodnoye
# Processing Record 43 of Set 8 | padang
# Processing Record 44 of Set 8 | bandarbeyla
# Processing Record 45 of Set 8 | arica
# Processing Record 46 of Set 8 | umtata
# Processing Record 47 of Set 8 | key biscayne
# Processing Record 48 of Set 8 | goderich
# Processing Record 49 of Set 8 | changping
# Processing Record 50 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 9 | ezhou
# Processing Record 2 of Set 9 | udachnyy
# Processing Record 3 of Set 9 | rawson
# Processing Record 4 of Set 9 | talaya
# Processing Record 5 of Set 9 | abu zabad
# Processing Record 6 of Set 9 | zhuhai
# Processing Record 7 of Set 9 | camalu
# Processing Record 8 of Set 9 | portel
# Processing Record 9 of Set 9 | sayyan
# Processing Record 10 of Set 9 | potamia
# Processing Record 11 of Set 9 | clyde river
# Processing Record 12 of Set 9 | sidi ali
# Processing Record 13 of Set 9 | kahului
# Processing Record 14 of Set 9 | korla
# Processing Record 15 of Set 9 | caserta
# Processing Record 16 of Set 9 | riyadh
# Processing Record 17 of Set 9 | iquitos
# Processing Record 18 of Set 9 | alihe
# Processing Record 19 of Set 9 | longyearbyen
# Processing Record 20 of Set 9 | san jeronimo
# Processing Record 21 of Set 9 | dentsville
# Processing Record 22 of Set 9 | tagusao
# Processing Record 23 of Set 9 | kruisfontein
# Processing Record 24 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 25 of Set 9 | clinton
# Processing Record 26 of Set 9 | los algarrobos
# Processing Record 27 of Set 9 | bissora
# Processing Record 28 of Set 9 | novikovo
# Processing Record 29 of Set 9 | zyryanka
# Processing Record 30 of Set 9 | mahebourg
# Processing Record 31 of Set 9 | santa fe
# Processing Record 32 of Set 9 | aripuana
# Processing Record 33 of Set 9 | north bend
# Processing Record 34 of Set 9 | brae
# Processing Record 35 of Set 9 | svetlyy
# Processing Record 36 of Set 9 | san quintin
# Processing Record 37 of Set 9 | eenhana
# Processing Record 38 of Set 9 | samana
# Processing Record 39 of Set 9 | sur
# Processing Record 40 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 41 of Set 9 | along
# Processing Record 42 of Set 9 | kushiro
# Processing Record 43 of Set 9 | gao
# Processing Record 44 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 45 of Set 9 | harper
# Processing Record 46 of Set 9 | beringovskiy
# Processing Record 47 of Set 9 | tynda
# Processing Record 48 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 9 | manggar
# Processing Record 50 of Set 9 | tocopilla
# Processing Record 1 of Set 10 | brokopondo
# Processing Record 2 of Set 10 | cayenne
# Processing Record 3 of Set 10 | zimovniki
# Processing Record 4 of Set 10 | katangli
# Processing Record 5 of Set 10 | santa cruz
# Processing Record 6 of Set 10 | monte azul
# Processing Record 7 of Set 10 | juarez
# Processing Record 8 of Set 10 | ban phai
# Processing Record 9 of Set 10 | prince rupert
# Processing Record 10 of Set 10 | bilecik
# Processing Record 11 of Set 10 | rotterdam
# Processing Record 12 of Set 10 | bismil
# Processing Record 13 of Set 10 | totness
# Processing Record 14 of Set 10 | hornepayne
# Processing Record 15 of Set 10 | kargasok
# Processing Record 16 of Set 10 | newport
# Processing Record 17 of Set 10 | novopokrovka
# Processing Record 18 of Set 10 | kualakapuas
# Processing Record 19 of Set 10 | mikuni
# Processing Record 20 of Set 10 | berck
# Processing Record 21 of Set 10 | slobodskoy
# Processing Record 22 of Set 10 | morgan city
# Processing Record 23 of Set 10 | pokrovsk
# Processing Record 24 of Set 10 | sulayman
# Processing Record 25 of Set 10 | eibar
# Processing Record 26 of Set 10 | komsomolskiy
# Processing Record 27 of Set 10 | panzhihua
# Processing Record 28 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 10 | gubkinskiy
# Processing Record 30 of Set 10 | honiara
# Processing Record 31 of Set 10 | san ramon
# Processing Record 32 of Set 10 | balaipungut
# Processing Record 33 of Set 10 | kattivakkam
# Processing Record 34 of Set 10 | lompoc
# Processing Record 35 of Set 10 | redcliffe
# Processing Record 36 of Set 10 | cradock
# Processing Record 37 of Set 10 | kyabe
# Processing Record 38 of Set 10 | ardon
# Processing Record 39 of Set 10 | balkhash
# Processing Record 40 of Set 10 | kangaba
# Processing Record 41 of Set 10 | ketchikan
# Processing Record 42 of Set 10 | carutapera
# Processing Record 43 of Set 10 | saint-pierre
# Processing Record 44 of Set 10 | lansdale
# Processing Record 45 of Set 10 | barra patuca
# Processing Record 46 of Set 10 | mpika
# Processing Record 47 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 10 | ancud
# Processing Record 49 of Set 10 | vila velha
# Processing Record 50 of Set 10 | barcelos
# Processing Record 1 of Set 11 | la rioja
# Processing Record 2 of Set 11 | pacific grove
# Processing Record 3 of Set 11 | lamar
# Processing Record 4 of Set 11 | inta
# Processing Record 5 of Set 11 | carballo
# Processing Record 6 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 11 | killin
# Processing Record 8 of Set 11 | nokaneng
# Processing Record 9 of Set 11 | nome
# Processing Record 10 of Set 11 | nieves
# Processing Record 11 of Set 11 | uyemskiy
# Processing Record 12 of Set 11 | myre
# Processing Record 13 of Set 11 | zaykovo
# Processing Record 14 of Set 11 | thaton
# Processing Record 15 of Set 11 | dondo
# Processing Record 16 of Set 11 | coolidge
# Processing Record 17 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | bani
# Processing Record 20 of Set 11 | miri
# Processing Record 21 of Set 11 | celestun
# Processing Record 22 of Set 11 | nuuk
# Processing Record 23 of Set 11 | beni
# Processing Record 24 of Set 11 | wanning
# Processing Record 25 of Set 11 | jacareacanga
# Processing Record 26 of Set 11 | bulgan
# Processing Record 27 of Set 11 | marawi
# Processing Record 28 of Set 11 | miranda
# Processing Record 29 of Set 11 | lufilufi
# Processing Record 30 of Set 11 | hualmay
# Processing Record 31 of Set 11 | verkhnevilyuysk
# Processing Record 32 of Set 11 | bichena
# Processing Record 33 of Set 11 | akureyri
# Processing Record 34 of Set 11 | jetis
# Processing Record 35 of Set 11 | mount isa
# Processing Record 36 of Set 11 | yerofey pavlovich
# Processing Record 37 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 38 of Set 11 | kimbe
# Processing Record 39 of Set 11 | zhanaozen
# Processing Record 40 of Set 11 | chardara
# Processing Record 41 of Set 11 | sabha
# Processing Record 42 of Set 11 | maceio
# Processing Record 43 of Set 11 | aizawl
# Processing Record 44 of Set 11 | buraydah
# Processing Record 45 of Set 11 | palm city
# Processing Record 46 of Set 11 | turbat
# Processing Record 47 of Set 11 | villa carlos paz
# Processing Record 48 of Set 11 | mehamn
# Processing Record 49 of Set 11 | kaabong
# Processing Record 50 of Set 11 | mayumba
# Processing Record 1 of Set 12 | wukari
# Processing Record 2 of Set 12 | kirkcudbright
# Processing Record 3 of Set 12 | alamos
# Processing Record 4 of Set 12 | kenai
# Processing Record 5 of Set 12 | radevormwald
# Processing Record 6 of Set 12 | thatta
# Processing Record 7 of Set 12 | antalaha
# Processing Record 8 of Set 12 | yaan
# Processing Record 9 of Set 12 | praya
# Processing Record 10 of Set 12 | biak
# Processing Record 11 of Set 12 | cheremisinovo
# Processing Record 12 of Set 12 | dumas
# Processing Record 13 of Set 12 | bilibino
# Processing Record 14 of Set 12 | erenhot
# Processing Record 15 of Set 12 | inirida
# Processing Record 16 of Set 12 | krasnopillya
# Processing Record 17 of Set 12 | eganville
# Processing Record 18 of Set 12 | galesong
# Processing Record 19 of Set 12 | charters towers
# Processing Record 20 of Set 12 | timra
# Processing Record 21 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 22 of Set 12 | pedernales
# Processing Record 23 of Set 12 | kano
# Processing Record 24 of Set 12 | syracuse
# Processing Record 25 of Set 12 | mielec
# Processing Record 26 of Set 12 | ridgecrest
# Processing Record 27 of Set 12 | alcantara
# Processing Record 28 of Set 12 | betioky
# Processing Record 29 of Set 12 | atar
# Processing Record 30 of Set 12 | alberdi
# Processing Record 31 of Set 12 | thinadhoo
# Processing Record 32 of Set 12 | caxito
# Processing Record 33 of Set 12 | itarema
# Processing Record 34 of Set 12 | darnah
# Processing Record 35 of Set 12 | kuragino
# Processing Record 36 of Set 12 | burgkirchen
# Processing Record 37 of Set 12 | jinan
# Processing Record 38 of Set 12 | souillac
# Processing Record 39 of Set 12 | koygorodok
# Processing Record 40 of Set 12 | berdigestyakh
# Processing Record 41 of Set 12 | namibe
# Processing Record 42 of Set 12 | harnai
# Processing Record 43 of Set 12 | porbandar
# Processing Record 44 of Set 12 | lang son
# Processing Record 45 of Set 12 | corinth
# Processing Record 46 of Set 12 | limbang
# Processing Record 47 of Set 12 | muros
# Processing Record 48 of Set 12 | hurghada
# Processing Record 49 of Set 12 | labuhan
# Processing Record 50 of Set 12 | hokitika
# Processing Record 1 of Set 13 | saldanha
# Processing Record 2 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 3 of Set 13 | auki
# Processing Record 4 of Set 13 | puerto ayacucho
# Processing Record 5 of Set 13 | moron
# Processing Record 6 of Set 13 | huambo
# Processing Record 7 of Set 13 | moanda
# Processing Record 8 of Set 13 | matto
# City not found. Skipping...
# Processing Record 9 of Set 13 | garissa
# Processing Record 10 of Set 13 | milton
# Processing Record 11 of Set 13 | bhum
# Processing Record 12 of Set 13 | media luna
# Processing Record 13 of Set 13 | puro
# Processing Record 14 of Set 13 | klaeng
# Processing Record 15 of Set 13 | bannu
# Processing Record 16 of Set 13 | victor harbor
# Processing Record 17 of Set 13 | kozhva
# Processing Record 18 of Set 13 | campbell river
# Processing Record 19 of Set 13 | kangaatsiaq
# Processing Record 20 of Set 13 | sola
# Processing Record 21 of Set 13 | antofagasta
# Processing Record 22 of Set 13 | praia
# Processing Record 23 of Set 13 | vizinga
# Processing Record 24 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 25 of Set 13 | ostersund
# Processing Record 26 of Set 13 | veraval
# Processing Record 27 of Set 13 | hammerfest
# Processing Record 28 of Set 13 | port hedland
# Processing Record 29 of Set 13 | strezhevoy
# Processing Record 30 of Set 13 | cockburn town
# Processing Record 31 of Set 13 | namatanai
# Processing Record 32 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 13 | seymchan
# Processing Record 34 of Set 13 | kazerun
# Processing Record 35 of Set 13 | makung
# City not found. Skipping...
# Processing Record 36 of Set 13 | dom pedro
# Processing Record 37 of Set 13 | ramhormoz
# Processing Record 38 of Set 13 | lazaro cardenas
# Processing Record 39 of Set 13 | oranjemund
# Processing Record 40 of Set 13 | lucapa
# Processing Record 41 of Set 13 | taltal
# Processing Record 42 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 43 of Set 13 | sol-iletsk
# Processing Record 44 of Set 13 | mayo
# Processing Record 45 of Set 13 | bollnas
# Processing Record 46 of Set 13 | ndjole
# Processing Record 47 of Set 13 | wasilla
# Processing Record 48 of Set 13 | south venice
# Processing Record 49 of Set 13 | ortakoy
# Processing Record 50 of Set 13 | te anau
# Processing Record 1 of Set 14 | omboue
# Processing Record 2 of Set 14 | bomet
# Processing Record 3 of Set 14 | peniche
# Processing Record 4 of Set 14 | bianzhuang
# Processing Record 5 of Set 14 | grand gaube
# Processing Record 6 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 14 | buenos aires
# Processing Record 8 of Set 14 | muli
# Processing Record 9 of Set 14 | vagamo
# Processing Record 10 of Set 14 | bilma
# Processing Record 11 of Set 14 | vasai
# Processing Record 12 of Set 14 | puerto leguizamo
# Processing Record 13 of Set 14 | abha
# Processing Record 14 of Set 14 | akom
# Processing Record 15 of Set 14 | naze
# Processing Record 16 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 14 | tipuani
# Processing Record 18 of Set 14 | dudinka
# Processing Record 19 of Set 14 | meulaboh
# Processing Record 20 of Set 14 | latehar
# Processing Record 21 of Set 14 | finote selam
# Processing Record 22 of Set 14 | chase
# Processing Record 23 of Set 14 | anuradhapura
# Processing Record 24 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 14 | katima mulilo
# Processing Record 26 of Set 14 | san francisco
# Processing Record 27 of Set 14 | san sebastian
# Processing Record 28 of Set 14 | tarare
# Processing Record 29 of Set 14 | evensk
# Processing Record 30 of Set 14 | jizan
# Processing Record 31 of Set 14 | nexo
# Processing Record 32 of Set 14 | cesme
# Processing Record 33 of Set 14 | springbok
# Processing Record 34 of Set 14 | madimba
# Processing Record 35 of Set 14 | chachapoyas
# Processing Record 36 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 14 | daru
# Processing Record 38 of Set 14 | yulara
# Processing Record 39 of Set 14 | luderitz
# Processing Record 40 of Set 14 | husavik
# Processing Record 41 of Set 14 | puerto rondon
# Processing Record 42 of Set 14 | palauig
# Processing Record 43 of Set 14 | tonantins
# Processing Record 44 of Set 14 | itoman
# Processing Record 45 of Set 14 | soe
# Processing Record 46 of Set 14 | novopavlovka
# Processing Record 47 of Set 14 | nanortalik
# Processing Record 48 of Set 14 | qurayyat
# Processing Record 49 of Set 14 | severo-yeniseyskiy
# Processing Record 50 of Set 14 | salta
# Processing Record 1 of Set 15 | weesp
# Processing Record 2 of Set 15 | hwange
# Processing Record 3 of Set 15 | isangel
# Processing Record 4 of Set 15 | capao da canoa
# Processing Record 5 of Set 15 | matay
# Processing Record 6 of Set 15 | zmievka
# City not found. Skipping...
# Processing Record 7 of Set 15 | nisia floresta
# Processing Record 8 of Set 15 | mbini
# Processing Record 9 of Set 15 | barranca
# Processing Record 10 of Set 15 | peleduy
# Processing Record 11 of Set 15 | presidente medici
# Processing Record 12 of Set 15 | suntar
# Processing Record 13 of Set 15 | terney
# Processing Record 14 of Set 15 | amahai
# Processing Record 15 of Set 15 | iquique
# Processing Record 16 of Set 15 | vanimo
# Processing Record 17 of Set 15 | yantal
# Processing Record 18 of Set 15 | eyl
# Processing Record 19 of Set 15 | kousseri
# Processing Record 20 of Set 15 | matamoros
# Processing Record 21 of Set 15 | dunedin
# Processing Record 22 of Set 15 | kazanskaya
# Processing Record 23 of Set 15 | nakambala
# Processing Record 24 of Set 15 | port hawkesbury
# Processing Record 25 of Set 15 | sangar
# Processing Record 26 of Set 15 | champerico
# Processing Record 27 of Set 15 | batagay
# Processing Record 28 of Set 15 | marsh harbour
# Processing Record 29 of Set 15 | darhan
# Processing Record 30 of Set 15 | burica
# City not found. Skipping...
# Processing Record 31 of Set 15 | westport
# Processing Record 32 of Set 15 | baruun-urt
# Processing Record 33 of Set 15 | lander
# Processing Record 34 of Set 15 | pau brasil
# Processing Record 35 of Set 15 | thanh hoa
# Processing Record 36 of Set 15 | misratah
# Processing Record 37 of Set 15 | dunda
# Processing Record 38 of Set 15 | adrar
# Processing Record 39 of Set 15 | paita
# Processing Record 40 of Set 15 | yerbogachen
# Processing Record 41 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 15 | preobrazheniye
# Processing Record 43 of Set 15 | farmington
# Processing Record 44 of Set 15 | toora-khem
# Processing Record 45 of Set 15 | lodja
# Processing Record 46 of Set 15 | sawtell
# Processing Record 47 of Set 15 | palmer
# Processing Record 48 of Set 15 | ayan
# Processing Record 49 of Set 15 | roblin
# Processing Record 50 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 1 of Set 16 | guangyuan
# Processing Record 2 of Set 16 | jardim
# Processing Record 3 of Set 16 | walvis bay
# Processing Record 4 of Set 16 | dubbo
# Processing Record 5 of Set 16 | beloha
# Processing Record 6 of Set 16 | roebourne
# Processing Record 7 of Set 16 | ikom
# Processing Record 8 of Set 16 | wamba
# Processing Record 9 of Set 16 | caucaia
# Processing Record 10 of Set 16 | gaoual
# Processing Record 11 of Set 16 | dingle
# Processing Record 12 of Set 16 | tamale
# Processing Record 13 of Set 16 | labytnangi
# Processing Record 14 of Set 16 | beckley
# Processing Record 15 of Set 16 | coronado
# Processing Record 16 of Set 16 | kutum
# Processing Record 17 of Set 16 | ilhabela
# Processing Record 18 of Set 16 | bandar-e lengeh
# Processing Record 19 of Set 16 | sahuaripa
# Processing Record 20 of Set 16 | mandalgovi
# Processing Record 21 of Set 16 | bac lieu
# Processing Record 22 of Set 16 | helong
# Processing Record 23 of Set 16 | tambul
# City not found. Skipping...
# Processing Record 24 of Set 16 | chemax
# Processing Record 25 of Set 16 | pangai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint Pete Beach  27.7253  -82.7412     63.34        72           0
# 1            Castro -24.7911  -50.0119     66.67        91          48
# 2           Qaanaaq  77.4840  -69.3632     -9.56        80          93
# 3       Honningsvag  70.9821   25.9704     19.54        86         100
# 4            Atuona  -9.8000 -139.0333     78.08        77          19
# 5             Vaini -21.2000 -175.2000     86.16        74          40
# 6           Osoyoos  49.0331 -119.4524     48.33        61          54
# 7           Bairiki   1.3292  172.9752     86.00        70          20
# 8           Mataura -46.1927  168.8643     62.47        48          37
# 9           Kambove -10.8764   26.5969     61.70        98          99
#
#    Wind Speed Country Current Description                 Date
# 0        8.05      US           clear sky  2022-02-13 23:23:23
# 1        4.47      BR    scattered clouds  2022-02-13 23:23:24
# 2        6.17      GL     overcast clouds  2022-02-13 23:23:24
# 3        7.25      NO          light snow  2022-02-13 23:23:24
# 4       12.91      PF          light rain  2022-02-13 23:23:25
# 5       13.80      TO    scattered clouds  2022-02-13 23:23:25
# 6        4.61      CA       broken clouds  2022-02-13 23:23:26
# 7        9.22      KI          few clouds  2022-02-13 23:23:26
# 8        2.28      NZ    scattered clouds  2022-02-13 23:23:10
# 9        3.20      CD          light rain  2022-02-13 23:23:27

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df.reindex(columns = new_column_order)

# %%
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Saint Pete Beach      US  27.7253  -82.7412     63.34        72
# 1            Castro      BR -24.7911  -50.0119     66.67        91
# 2           Qaanaaq      GL  77.4840  -69.3632     -9.56        80
# 3       Honningsvag      NO  70.9821   25.9704     19.54        86
# 4            Atuona      PF  -9.8000 -139.0333     78.08        77
# 5             Vaini      TO -21.2000 -175.2000     86.16        74
# 6           Osoyoos      CA  49.0331 -119.4524     48.33        61
# 7           Bairiki      KI   1.3292  172.9752     86.00        70
# 8           Mataura      NZ -46.1927  168.8643     62.47        48
# 9           Kambove      CD -10.8764   26.5969     61.70        98
#
#    Cloudiness  Wind Speed Current Description
# 0           0        8.05           clear sky
# 1          48        4.47    scattered clouds
# 2          93        6.17     overcast clouds
# 3         100        7.25          light snow
# 4          19       12.91          light rain
# 5          40       13.80    scattered clouds
# 6          54        4.61       broken clouds
# 7          20        9.22          few clouds
# 8          37        2.28    scattered clouds
# 9          99        3.20          light rain

# %%
#  8. Format the columns 
pd.options.display.float_format = "{:.2f}".format

# creates pandas DataFrame
city_data_df.head(10)
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint Pete Beach      US  27.73  -82.74     63.34        72           0
# 1            Castro      BR -24.79  -50.01     66.67        91          48
# 2           Qaanaaq      GL  77.48  -69.36     -9.56        80          93
# 3       Honningsvag      NO  70.98   25.97     19.54        86         100
# 4            Atuona      PF  -9.80 -139.03     78.08        77          19
# 5             Vaini      TO -21.20 -175.20     86.16        74          40
# 6           Osoyoos      CA  49.03 -119.45     48.33        61          54
# 7           Bairiki      KI   1.33  172.98     86.00        70          20
# 8           Mataura      NZ -46.19  168.86     62.47        48          37
# 9           Kambove      CD -10.88   26.60     61.70        98          99
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1        4.47    scattered clouds
# 2        6.17     overcast clouds
# 3        7.25          light snow
# 4       12.91          light rain
# 5       13.80    scattered clouds
# 6        4.61       broken clouds
# 7        9.22          few clouds
# 8        2.28    scattered clouds
# 9        3.20          light rain

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="Weather_ID")
